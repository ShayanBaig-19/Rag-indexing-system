# %%
import os

# %%
from dotenv import load_dotenv

load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
print(os.getenv("mistral"))
# Out:
# V7SlGNy2FmomyWAeQVNyhsvHS2czLoC3

# %%
from langchain_mistralai import MistralAIEmbeddings

# %%
mkdir data

# %%
from langchain_community.document_loaders import PyPDFLoader
# Out:
# C:\Users\Mirza Shayan Baig\AppData\Local\Temp\ipykernel_18492\4175148793.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
print(os.path.exists("../data/summary-islamhand (1).pdf"))
# Out:
# True

# %%
loader = PyPDFLoader("../data/summary-islamhand (1).pdf")
documents = loader.load()

# %%
print(documents[0].page_content)
# Out:
# 1: Leye E, Van Eekert N, Shamu S, Esho T, Barrett H; ANSER. Debating
# medicalization of Female Genital Mutilation/Cutting (FGM/C): learning from
# (policy) experiences across countries. Reprod Health. 2019 Nov 1;16(1):158. doi:
# 10.1186/s12978-019-0817-3. PMID: 31675972; PMCID: PMC6823951.
# 2: Kimani S, Kabiru CW, Muteshi J, Guyo J. Female genital mutilation/cutting:
# Emerging factors sustaining medicalization related changes in selected Kenyan
# communities. PLoS One. 2020 Mar 2;15(3):e0228410. doi:
# 10.1371/journal.pone.0228410. PMID: 32119680; PMCID: PMC7051066.
# 3: Elnakib S, Sallab M, Hussein A, Marouf M, Elshiwy S, Elsherbini R, Daggula K,
# Prihartono I. Medicalization of female genital mutilation in Egypt: Trends,
# drivers, and prospects for elimination. PLOS Glob Public Health. 2025 Nov
# 20;5(11):e0005195. doi: 10.1371/journal.pgph.0005195. PMID: 41264580; PMCID:
# PMC12633923.
# 4: Tekbaş A, von Lilienfeld-Toal M, Sayrafi F, Settmacher U. Perioperative
# medication therapy for Muslim patients in Germany undergoing oncological
# surgery: a retrospective study. BMC Med Ethics. 2024 Oct 18;25(1):116. doi:
# 10.1186/s12910-024-01114-z. PMID: 39425135; PMCID: PMC11487790.
# 5: El-Gibaly O, Aziz M, Abou Hussein S. Health care providers' and mothers'
# perceptions about the medicalization of female genital mutilation or cutting in
# Egypt: a cross-sectional qualitative study. BMC Int Health Hum Rights. 2019 Aug
# 27;19(1):26. doi: 10.1186/s12914-019-0202-x. PMID: 31455345; PMCID: PMC6712689.
# 6: Sedigh Mobarakabadi S, Mirzaei Najmabadi K, Ghazi Tabatabaie M. Ambivalence
# towards childbirth in a medicalized context: a qualitative inquiry among Iranian
# mothers. Iran Red Crescent Med J. 2015 Mar 20;17(3):e24262. doi:
# 10.5812/ircmj.24262. PMID: 26019905; PMCID: PMC4441778.
# 7: Rashid A, Iguchi Y, Afiqah SN. Medicalization of female genital cutting in
# Malaysia: A mixed methods study. PLoS Med. 2020 Oct 27;17(10):e1003303. doi:
# 10.1371/journal.pmed.1003303. PMID: 33108371; PMCID: PMC7591112.
# 8: Hehmeyer I, Khan A. Islam's forgotten contributions to medical science. CMAJ.
# 2007 May 8;176(10):1467–8. doi: 10.1503/cmaj.061464. PMCID: PMC1863528.
# 9: Miller AC, Ziad-Miller A, Elamin EM. Brain death and Islam: the interface of
# religion, culture, history, law, and modern medicine. Chest. 2014
# Oct;146(4):1092-1101. doi: 10.1378/chest.14-0130. PMID: 25287999; PMCID:
# PMC4188144.
# 10: Rispler-Chaim V. Islamic medical ethics in the 20th century. J Med Ethics.
# 1989 Dec;15(4):203-8. doi: 10.1136/jme.15.4.203. PMID: 2614792; PMCID:
# PMC1375837.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_split = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=150
)

# %%
chunks = text_split.split_documents(documents)

# %%
len(chunks)
# Out:
# 7

# %%
chunks[0]
# Out:
# Document(metadata={'producer': 'LibreOffice 24.8.1.2 (X86_64) / LibreOffice Community', 'creator': 'Writer', 'creationdate': '2026-07-13T00:16:23+00:00', 'source': '../data/summary-islamhand (1).pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='1: Leye E, Van Eekert N, Shamu S, Esho T, Barrett H; ANSER. Debating\nmedicalization of Female Genital Mutilation/Cutting (FGM/C): learning from\n(policy) experiences across countries. Reprod Health. 2019 Nov 1;16(1):158. doi:\n10.1186/s12978-019-0817-3. PMID: 31675972; PMCID: PMC6823951.\n2: Kimani S, Kabiru CW, Muteshi J, Guyo J. Female genital mutilation/cutting:\nEmerging factors sustaining medicalization related changes in selected Kenyan\ncommunities. PLoS One. 2020 Mar 2;15(3):e0228410. doi:')
